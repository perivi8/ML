# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("G:\simple linear regression data.csv")
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
x = df[['YearsExperience']]
x
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y = df[['Salary']]
y
# Out:
#     Salary
# 0    39343
# 1    46205
# 2    37731
# 3    43525
# 4    39891
# 5    56642
# 6    60150
# 7    54445
# 8    64445
# 9    57189
# 10   63218
# 11   55794
# 12   56957
# 13   57081
# 14   61111
# 15   67938
# 16   66029
# 17   83088
# 18   81363
# 19   93940
# 20   91738
# 21   98273
# 22  101302
# 23  113812
# 24  109431
# 25  105582
# 26  116969
# 27  112635
# 28  122391
# 29  121872

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x , y)
plt.title('graph')
plt.xlabel('age')
plt.ylabel('Dob')

plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y , test_size= 0.2)  # write this like omly(x_train , x_test , y_train , y_test)

# %%
x_train
# Out:
#     YearsExperience
# 0               1.1
# 14              4.5
# 11              4.0
# 1               1.3
# 20              6.8
# 19              6.0
# 2               1.5
# 12              4.0
# 15              4.9
# 4               2.2
# 9               3.7
# 24              8.7
# 21              7.1
# 22              7.9
# 6               3.0
# 23              8.2
# 26              9.5
# 25              9.0
# 13              4.1
# 17              5.3
# 16              5.1
# 10              3.9
# 28             10.3
# 7               3.2

# %%
x_train = np.array(x_train)    # we need to convert the one dimensional array into two dimensional array [x_train , x_test]
x_train
# Out:
# array([[ 1.1],
#        [ 4.5],
#        [ 4. ],
#        [ 1.3],
#        [ 6.8],
#        [ 6. ],
#        [ 1.5],
#        [ 4. ],
#        [ 4.9],
#        [ 2.2],
#        [ 3.7],
#        [ 8.7],
#        [ 7.1],
#        [ 7.9],
#        [ 3. ],
#        [ 8.2],
#        [ 9.5],
#        [ 9. ],
#        [ 4.1],
#        [ 5.3],
#        [ 5.1],
#        [ 3.9],
#        [10.3],
#        [ 3.2]])

# %%
x_test
# Out:
#     YearsExperience
# 3               2.0
# 29             10.5
# 27              9.6
# 5               2.9
# 18              5.9
# 8               3.2

# %%
x_test = np.array(x_test)
x_test
# Out:
# array([[ 2. ],
#        [10.5],
#        [ 9.6],
#        [ 2.9],
#        [ 5.9],
#        [ 3.2]])

# %%
y_train        # no need to convert the y_train and y_test
# Out:
#     Salary
# 0    39343
# 14   61111
# 11   55794
# 1    46205
# 20   91738
# 19   93940
# 2    37731
# 12   56957
# 15   67938
# 4    39891
# 9    57189
# 24  109431
# 21   98273
# 22  101302
# 6    60150
# 23  113812
# 26  116969
# 25  105582
# 13   57081
# 17   83088
# 16   66029
# 10   63218
# 28  122391
# 7    54445

# %%
y_test
# Out:
#     Salary
# 3    43525
# 29  121872
# 27  112635
# 5    56642
# 18   81363
# 8    64445

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
z = reg.predict(x_test)
z
# Out:
# array([[ 43483.85200862],
#        [126614.02264564],
#        [117812.00457819],
#        [ 52285.87007607],
#        [ 81625.9303009 ],
#        [ 55219.87609855]])

# %%
y_test
# Out:
#     Salary
# 3    43525
# 29  121872
# 27  112635
# 5    56642
# 18   81363
# 8    64445

# %% [markdown]
# ###  We need to find the m and c and then we put it on y = mx + c

# %% [markdown]
# ###  y = mx+c

# %%
c = reg.intercept_
c
# Out:
# array([23923.81185873])

# %%
m = reg.coef_
m
# Out:
# array([[9780.02007494]])

# %%
y = m*x_train + c      # this is for x_train
y
# Out:
# array([[ 34681.83394117],
#        [ 67933.90219598],
#        [ 63043.89215851],
#        [ 36637.83795616],
#        [ 90427.94836835],
#        [ 82603.93230839],
#        [ 38593.84197115],
#        [ 63043.89215851],
#        [ 71845.91022596],
#        [ 45439.85602361],
#        [ 60109.88613602],
#        [109009.98651074],
#        [ 93361.95439083],
#        [101185.97045079],
#        [ 53263.87208356],
#        [104119.97647327],
#        [116834.00257069],
#        [111943.99253322],
#        [ 64021.894166  ],
#        [ 75757.91825593],
#        [ 73801.91424094],
#        [ 62065.89015101],
#        [124658.01863065],
#        [ 55219.87609855]])

# %% [markdown]
# ##  or we will do the predict method

# %%
reg.predict(x_train)    # this is also for x_train
# Out:
# array([[ 34681.83394117],
#        [ 67933.90219598],
#        [ 63043.89215851],
#        [ 36637.83795616],
#        [ 90427.94836835],
#        [ 82603.93230839],
#        [ 38593.84197115],
#        [ 63043.89215851],
#        [ 71845.91022596],
#        [ 45439.85602361],
#        [ 60109.88613602],
#        [109009.98651074],
#        [ 93361.95439083],
#        [101185.97045079],
#        [ 53263.87208356],
#        [104119.97647327],
#        [116834.00257069],
#        [111943.99253322],
#        [ 64021.894166  ],
#        [ 75757.91825593],
#        [ 73801.91424094],
#        [ 62065.89015101],
#        [124658.01863065],
#        [ 55219.87609855]])

# %% [markdown]
# # This is the graph for x_train

# %%
plt.scatter(x_train , y_train , color = 'g')
plt.plot(x_train,y , 'r')

# wrong process 

# plt.scatter(x_test , y_test)
# plt.plot(x_test,y1 , 'r')

# %%
y1 = m*x_test + c     # this is for x_test
y1

# %%
reg.predict(x_test)  # this is also for x_test

# %% [markdown]
# ## This is the graph of x_test

# %%
plt.scatter(x_test , y_test)
plt.plot(x_test,y1 , 'r')

# wrong pracess 

# plt.scatter(x_test , y_test)
# plt.plot(x_train,y1 , 'r')

# %% [markdown]
# ##  The below methods will not work

# %%
# y2 = m*y_train + c     
# y2

# y3 = m*y_test + c
# y3

# reg.predicte(y_train)
# reg.predicte(y_test)
