# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("G:\multiple linear regression data.csv")
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# ## First we need to check is there any na() values

# %%
df.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %% [markdown]
# ## we need to change objects into numerical values

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
df['State'] = label_encoder.fit_transform(df['State'])
df[["State"]]
# Out:
#     State
# 0       2
# 1       0
# 2       1
# 3       2
# 4       1
# 5       2
# 6       0
# 7       1
# 8       2
# 9       0
# 10      1
# 11      0
# 12      1
# 13      0
# 14      1
# 15      2
# 16      0
# 17      2
# 18      1
# 19      2
# 20      0
# 21      2
# 22      1
# 23      1
# 24      2
# 25      0
# 26      1
# 27      2
# 28      1
# 29      2
# 30      1
# 31      2
# 32      0
# 33      1
# 34      0
# 35      2
# 36      1
# 37      0
# 38      2
# 39      0
# 40      0
# 41      1
# 42      0
# 43      2
# 44      0
# 45      2
# 46      1
# 47      0
# 48      2
# 49      0

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend  State     Profit
# 0   165349.20       136897.80        471784.10      2  192261.83
# 1   162597.70       151377.59        443898.53      0  191792.06
# 2   153441.51       101145.55        407934.54      1  191050.39
# 3   144372.41       118671.85        383199.62      2  182901.99
# 4   142107.34        91391.77        366168.42      1  166187.94
# 5   131876.90        99814.71        362861.36      2  156991.12
# 6   134615.46       147198.87        127716.82      0  156122.51
# 7   130298.13       145530.06        323876.68      1  155752.60
# 8   120542.52       148718.95        311613.29      2  152211.77
# 9   123334.88       108679.17        304981.62      0  149759.96
# 10  101913.08       110594.11        229160.95      1  146121.95
# 11  100671.96        91790.61        249744.55      0  144259.40
# 12   93863.75       127320.38        249839.44      1  141585.52
# ...

# %%
x = df[['R&D Spend' , 'Administration' , 'Marketing Spend' , 'State']]
x
# Out:
#     R&D Spend  Administration  Marketing Spend  State
# 0   165349.20       136897.80        471784.10      2
# 1   162597.70       151377.59        443898.53      0
# 2   153441.51       101145.55        407934.54      1
# 3   144372.41       118671.85        383199.62      2
# 4   142107.34        91391.77        366168.42      1
# 5   131876.90        99814.71        362861.36      2
# 6   134615.46       147198.87        127716.82      0
# 7   130298.13       145530.06        323876.68      1
# 8   120542.52       148718.95        311613.29      2
# 9   123334.88       108679.17        304981.62      0
# 10  101913.08       110594.11        229160.95      1
# 11  100671.96        91790.61        249744.55      0
# 12   93863.75       127320.38        249839.44      1
# 13   91992.39       135495.07        252664.93      0
# 14  119943.24       156547.42        256512.92      1
# 15  114523.61       122616.84        261776.23      2
# ...

# %%
y = df[['Profit']]
y
# Out:
#        Profit
# 0   192261.83
# 1   191792.06
# 2   191050.39
# 3   182901.99
# 4   166187.94
# 5   156991.12
# 6   156122.51
# 7   155752.60
# 8   152211.77
# 9   149759.96
# 10  146121.95
# 11  144259.40
# 12  141585.52
# 13  134307.35
# 14  132602.65
# 15  129917.04
# 16  126992.93
# 17  125370.37
# 18  124266.90
# 19  122776.86
# 20  118474.03
# 21  111313.02
# 22  110352.25
# 23  108733.99
# 24  108552.04
# 25  107404.34
# 26  105733.54
# 27  105008.31
# 28  103282.38
# 29  101004.64
# 30   99937.59
# 31   97483.56
# 32   97427.84
# 33   96778.92
# 34   96712.80
# 35   96479.51
# 36   90708.19
# 37   89949.14
# 38   81229.06
# 39   81005.76
# 40   78239.91
# 41   77798.83
# 42   71498.49
# 43   69758.98
# 44   65200.33
# 45   64926.08
# 46   49490.75
# 47   42559.73
# 48   35673.41
# 49   14681.40

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size= 0.2)

# %%
x_train
# Out:
#     R&D Spend  Administration  Marketing Spend  State
# 28   66051.52       182645.56        118148.20      1
# 23   67532.53       105751.03        304768.73      1
# 41   27892.92        84710.77        164470.71      1
# 17   94657.16       145077.58        282574.31      2
# 9   123334.88       108679.17        304981.62      0
# 21   78389.47       153773.43        299737.29      2
# 5   131876.90        99814.71        362861.36      2
# 42   23640.93        96189.63        148001.11      0
# 43   15505.73       127382.30         35534.17      2
# 45    1000.23       124153.04          1903.93      2
# 32   63408.86       129219.61         46085.25      0
# 12   93863.75       127320.38        249839.44      1
# 46    1315.46       115816.21        297114.46      1
# 37   44069.95        51283.14        197029.42      0
# 8   120542.52       148718.95        311613.29      2
# 33   55493.95       103057.49        214634.81      1
# ...

# %%
x_test
# Out:
#     R&D Spend  Administration  Marketing Spend  State
# 2   153441.51       101145.55        407934.54      1
# 19   86419.70       153514.11             0.00      2
# 1   162597.70       151377.59        443898.53      0
# 3   144372.41       118671.85        383199.62      2
# 18   91749.16       114175.79        294919.57      1
# 27   72107.60       127864.55        353183.81      2
# 14  119943.24       156547.42        256512.92      1
# 40   28754.33       118546.05        172795.67      0
# 22   73994.56       122782.75        303319.26      1
# 34   46426.07       157693.92        210797.67      0

# %%
y_train
# Out:
#        Profit
# 28  103282.38
# 23  108733.99
# 41   77798.83
# 17  125370.37
# 9   149759.96
# 21  111313.02
# 5   156991.12
# 42   71498.49
# 43   69758.98
# 45   64926.08
# 32   97427.84
# 12  141585.52
# 46   49490.75
# 37   89949.14
# 8   152211.77
# 33   96778.92
# 16  126992.93
# 39   81005.76
# 7   155752.60
# 49   14681.40
# 15  129917.04
# 31   97483.56
# 0   192261.83
# 26  105733.54
# 44   65200.33
# 20  118474.03
# 10  146121.95
# 47   42559.73
# 30   99937.59
# 24  108552.04
# 4   166187.94
# 48   35673.41
# 25  107404.34
# 13  134307.35
# 29  101004.64
# 11  144259.40
# 36   90708.19
# 35   96479.51
# 6   156122.51
# 38   81229.06

# %%
y_test
# Out:
#        Profit
# 2   191050.39
# 19  122776.86
# 1   191792.06
# 3   182901.99
# 18  124266.90
# 27  105008.31
# 14  132602.65
# 40   78239.91
# 22  110352.25
# 34   96712.80

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(x_train , y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # y = mx + c

# %% [markdown]
# ## In Multiple Linear Regression y = mx + c does not work

# %%
m = reg.coef_
m
# Out:
# array([[ 7.81628632e-01, -9.12562729e-03,  3.50360418e-02,
#          1.68752138e+02]])

# %%
c = reg.intercept_
c
# Out:
# array([47888.34361281])

# %%
# y = m*x_test + c         # this will not work because in X_train they are more columns
# y

# %% [markdown]
# ### We need to predict only x_train ( or ) x_test , not   y_train ,   y_test

# %% [markdown]
# ### x_train

# %%
Y= reg.predict(x_train)
Y
# Out:
# array([[102157.54492034],
#        [110555.30025977],
#        [ 74848.36440665],
#        [130788.95576335],
#        [153984.00030585],
#        [118595.6312874 ],
#        [163106.96273619],
#        [ 70674.35375053],
#        [ 60428.10368479],
#        [ 47941.38809527],
#        [ 97885.95883874],
#        [129015.19696692],
#        [ 58438.11603644],
#        [ 88769.81851116],
#        [152005.87541365],
#        [ 98012.24589644],
#        [117017.60973378],
#        [ 83400.79819596],
#        [159921.14863832],
#        [ 48403.47827516],
#        [145793.427834  ],
#        [ 97709.10972237],
#        [192747.68600262],
#        [110317.54996345],
#        [ 64803.13348215],
#        [116915.45419265],
#        [134734.92902587],
#        [ 46652.48801556],
#        [ 98651.33504168],
#        [112464.83242306],
#        [171127.34632093],
#        [ 48177.34098607],
#        [101992.28640976],
#        [127408.1310848 ],
#        [101862.16067272],
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_train , Y , color ='g')

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train,Y)
# Out:
# 0.9456517460497714

# %% [markdown]
# ### x_test

# %%
Y1 = reg.predict(x_test)
Y1
# Out:
# array([[181360.76827628],
#        [114373.04719741],
#        [189150.39338309],
#        [173414.3000166 ],
#        [129061.75482891],
#        [115794.53112847],
#        [149366.77030118],
#        [ 75335.82048092],
#        [115399.99910611],
#        [ 90122.74922779]])

# %%
plt.scatter(y_test,Y1)

# %%
r2_score(y_test,Y1)
# Out:
# 0.9497410190644597

# %%
# The r2_score is between the 0 to 1
# If the value is closer to 1 then the code is good
# If the value is closer to 0 then the code is bad
